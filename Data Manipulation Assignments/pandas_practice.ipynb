# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
t_data = sns.load_dataset("titanic")
t_data.to_csv('titanic data.csv')
t_data.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
t_data1 = t_data.drop(["fare", "embarked", "embark_town"], axis= 1)
t_data1
# Out:
#      survived  pclass     sex   age  sibsp  parch   class    who  adult_male  \
# 0           0       3    male  22.0      1      0   Third    man        True
# 1           1       1  female  38.0      1      0   First  woman       False
# 2           1       3  female  26.0      0      0   Third  woman       False
# 3           1       1  female  35.0      1      0   First  woman       False
# 4           0       3    male  35.0      0      0   Third    man        True
# ..        ...     ...     ...   ...    ...    ...     ...    ...         ...
# 886         0       2    male  27.0      0      0  Second    man        True
# 887         1       1  female  19.0      0      0   First  woman       False
# 888         0       3  female   NaN      1      2   Third  woman       False
# 889         1       1    male  26.0      0      0   First    man        True
# 890         0       3    male  32.0      0      0   Third    man        True
#
#     deck alive  alone
# ...

# %%
t_data1.groupby(['sex']).mean()
# Out:
#         survived    pclass        age     sibsp     parch  adult_male  \
# sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682    0.000000
# male    0.188908  2.389948  30.726645  0.429809  0.235702    0.930676
#
#            alone
# sex
# female  0.401274
# male    0.712305

# %%
t_data1.groupby(['sex', 'class', 'survived']).mean()
# Out:
#                         pclass        age     sibsp     parch  adult_male  \
# sex    class  survived
# female First  0            1.0  25.666667  0.666667  1.333333    0.000000
#               1            1.0  34.939024  0.549451  0.428571    0.000000
#        Second 0            2.0  36.000000  0.500000  0.166667    0.000000
#               1            2.0  28.080882  0.485714  0.642857    0.000000
#        Third  0            3.0  23.818182  1.291667  1.097222    0.000000
#               1            3.0  19.329787  0.500000  0.500000    0.000000
# male   First  0            1.0  44.581967  0.272727  0.259740    1.000000
#               1            1.0  36.248000  0.377778  0.311111    0.933333
#        Second 0            2.0  33.369048  0.307692  0.142857    1.000000
#               1            2.0  16.022000  0.529412  0.647059    0.470588
#        Third  0            3.0  27.255814  0.523333  0.213333    0.936667
# ...

# %%
t_data1[t_data1['age'] < 18].groupby(['sex', 'class', 'survived']).mean()
# Out:
#                         pclass        age     sibsp     parch  adult_male  \
# sex    class  survived
# female First  0            1.0   2.000000  1.000000  2.000000    0.000000
#               1            1.0  15.857143  0.428571  0.714286    0.000000
#        Second 0            NaN        NaN       NaN       NaN         NaN
#               1            2.0   8.333333  0.583333  1.083333    0.000000
#        Third  0            3.0   8.843750  2.312500  1.375000    0.000000
#               1            3.0   8.078947  0.947368  0.789474    0.000000
# male   First  0            NaN        NaN       NaN       NaN         NaN
#               1            1.0   8.230000  0.500000  2.000000    0.250000
#        Second 0            2.0  16.000000  0.000000  0.000000    1.000000
#               1            2.0   2.258889  0.888889  1.222222    0.000000
#        Third  0            3.0  11.060606  2.424242  0.969697    0.424242
# ...

# %%
t_data1.describe()
# Out:
#          survived      pclass         age       sibsp       parch
# count  891.000000  891.000000  714.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594
# std      0.486592    0.836071   14.526497    1.102743    0.806057
# min      0.000000    1.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000

# %%
#nunique checks the varible - how many unique values are in one column
t_data1.nunique()
# Out:
# survived       2
# pclass         3
# sex            2
# age           88
# sibsp          7
# parch          7
# class          3
# who            3
# adult_male     2
# deck           7
# alive          2
# alone          2
# dtype: int64

# %%
t_data1.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'class', 'who',
#        'adult_male', 'deck', 'alive', 'alone'],
#       dtype='object')

# %%
#unique and nunique gives the variability
t_data1['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
t_data1['age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
t_data1[["age", "class"]].nunique()
# Out:
# age      88
# class     3
# dtype: int64

# %%
#finding null values
t_data1.isnull().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age           177
# sibsp           0
# parch           0
# class           0
# who             0
# adult_male      0
# deck          688
# alive           0
# alone           0
# dtype: int64

# %%
t_data1.shape
# Out:
# (891, 11)

# %%
t_data1.describe()
# Out:
#          survived      pclass         age       sibsp       parch
# count  891.000000  891.000000  714.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594
# std      0.486592    0.836071   14.526497    1.102743    0.806057
# min      0.000000    1.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000

# %%
t_data1['age'].mean()
# Out:
# 29.69911764705882

# %%
sns.boxplot(x=  'sex', y= 'age', data=t_data1)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.displot(t_data1['age'], kind= 'hist', bins=20, stat= 'density')

# %%
for a in t_data1.index:
    if t_data1.loc[a, 'age'] > 66:
        t_data1.loc[a, 'age'].drop()

# %%
for x in t_data1.index:
     if t_data1.loc[x, 'age'] > 66:
        t_data1.loc[x, 'age'].drop()

t_data1.max()
# Out:
# C:\Users\MohHu\AppData\Local\Temp\ipykernel_1260\1763077445.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   t_data1.max()
# survived          1
# pclass            3
# sex            male
# age            66.0
# sibsp             5
# parch             6
# who           woman
# adult_male     True
# alive           yes
# alone          True
# dtype: object

# %%
sns.boxplot(x= 'sex', y='age', data = t_data1)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.displot(t_data1['age'])

# %%
t_data1['survived'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>
